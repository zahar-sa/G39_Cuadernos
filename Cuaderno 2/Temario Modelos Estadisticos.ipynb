# %%
**Temario de Modelos estadisticos **  

<img src="/home/usr/Imágenes/Capturas de pantalla/Modulo II. Modelos estadisticos.png" width="400" height="300" alt="Descripción">

# %% [markdown]
# **Temario de Modelos estadisticos **
#
# <img src="/home/usr/Imágenes/Capturas de pantalla/Modelosestadisticos.png" width="400" height="300" alt="Modelos Estadisticos">
# <img src="/home/usr/Imágenes/Capturas%20de%20pantalla/Modelosestadisticos.png" width="400" height="300">
# <img src="/home/usr/Imágenes/Capturas\ de\ pantalla/Modelosestadisticos.png" width="400" height="300">
# ![Modelos Estadisticos](/home/usr/Imágenes/Capturas%20de%20pantalla/Modelosestadisticos.png)
